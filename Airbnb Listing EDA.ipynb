# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\HP\\Downloads\\airbnb.csv')

# %%
data
# Out:
#                        id                                      listing_url  \
# 0                  231497              https://www.airbnb.com/rooms/231497
# 1                  231516              https://www.airbnb.com/rooms/231516
# 2                  236991              https://www.airbnb.com/rooms/236991
# 3                   17878               https://www.airbnb.com/rooms/17878
# 4                   25026               https://www.airbnb.com/rooms/25026
# ...                   ...                                              ...
# 31959  985064291460771751  https://www.airbnb.com/rooms/985064291460771751
# 31960  985340991466900379  https://www.airbnb.com/rooms/985340991466900379
# 31961  985507696630141934  https://www.airbnb.com/rooms/985507696630141934
# 31962  985510361579508644  https://www.airbnb.com/rooms/985510361579508644
# 31963  985555107088259155  https://www.airbnb.com/rooms/985555107088259155
#
#             scrape_id last_scraped       source  \
# ...

# %%
data.shape
# Out:
# (31964, 75)

# %%
print('\nRows : ',data.shape[0])
print('\nColumns :', data.shape[1])
print('\nColumns:',data.columns.to_list())
print(' \nUnique:\n',data.nunique())
# Out:
# Rows :  31964
#
# Columns : 75
#
# ...

# %%
columns_to_drop = ['id', 'listing_url', 'scrape_id','last_scraped','host_about','host_thumbnail_url', 'host_picture_url','host_verifications','host_has_profile_pic','host_identity_verified','latitude', 'longitude','calendar_last_scraped']
data.drop(columns_to_drop, axis=1, inplace=True)

# %%
data.shape
# Out:
# (31964, 61)

# %%
data.isnull()
# Out:
#        source   name  description  neighborhood_overview  host_id  host_url  \
# 0       False  False        False                   True    False     False
# 1       False  False        False                   True    False     False
# 2       False  False        False                  False    False     False
# 3       False  False        False                  False    False     False
# 4       False  False        False                  False    False     False
# ...       ...    ...          ...                    ...      ...       ...
# 31959   False  False        False                   True    False     False
# 31960   False  False        False                  False    False     False
# 31961   False  False        False                   True    False     False
# 31962   False  False        False                  False    False     False
# 31963   False  False        False                   True    False     False
#
# ...

# %%
missing_values=data.isnull().sum()
missing_values
# Out:
# source                                              0
# name                                                0
# description                                       659
# neighborhood_overview                           15225
# host_id                                             0
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                8140
# Length: 61, dtype: int64

# %%
missing_values /data.shape[0]
# Out:
# source                                          0.000000
# name                                            0.000000
# description                                     0.020617
# neighborhood_overview                           0.476317
# host_id                                         0.000000
#                                                   ...
# calculated_host_listings_count                  0.000000
# calculated_host_listings_count_entire_homes     0.000000
# calculated_host_listings_count_private_rooms    0.000000
# calculated_host_listings_count_shared_rooms     0.000000
# reviews_per_month                               0.254661
# Length: 61, dtype: float64

# %%
data.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 3169     25
# 5500     25
# 12776    24
# 11191    23
# 12986    23
#          ..
# 24962     4
# 9834      4
# 24960     4
# 9836      4
# 15982     4
# Length: 31964, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data=train_test_split(data, test_size=0.3,random_state=42)

# %%
train_data.shape ,test_data.shape
# Out:
# ((22374, 61), (9590, 61))

# %%
train_data['neighborhood_overview'].fillna('unknown', inplace=True)
test_data['neighborhood_overview'].fillna('unknown', inplace=True)

# %%
data
# Out:
#             source                                               name  \
# 0      city scrape  Rental unit in Rio de Janeiro · ★4.73 · 1 bedr...
# 1      city scrape  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...
# 2      city scrape  Rental unit in Rio de Janeiro · ★4.89 · 1 bedr...
# 3      city scrape  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...
# 4      city scrape  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...
# ...            ...                                                ...
# 31959  city scrape  Rental unit in Rio de Janeiro · ★New · 1 bedro...
# 31960  city scrape  Rental unit in Rio de Janeiro · ★New · 2 bedro...
# 31961  city scrape  Rental unit in Rio de Janeiro · ★New · 1 bedro...
# 31962  city scrape  Rental unit in Rio de Janeiro · ★New · 2 bedro...
# 31963  city scrape  Rental unit in Rio de Janeiro · ★New · 1 bedro...
#
#                                              description  \
# 0      This is a big studio at the end of Copacabana,...
# ...

# %%
test_data
# Out:
#             source                                               name  \
# 12228  city scrape  Condo in Barra da Tijuca · 3 bedrooms · 4 beds...
# 16265  city scrape  Rental unit in Laranjeiras · 2 bedrooms · 2 be...
# 19321  city scrape  Rental unit in Copacabana · ★4.89 · 1 bedroom ...
# 4308   city scrape  Home in Rio de Janeiro · ★4.88 · 1 bedroom · 1...
# 23872  city scrape  Rental unit in Rio de Janeiro · 3 bedrooms · 3...
# ...            ...                                                ...
# 13352  city scrape  Serviced apartment in Ipanema · 2 bedrooms · 3...
# 23007  city scrape  Rental unit in Rio de Janeiro · 1 bedroom · 1 ...
# 10883  city scrape  Rental unit in Vila Isabel · ★4.84 · 1 bedroom...
# 6084   city scrape  Rental unit in Rio de Janeiro · ★4.70 · 1 bedr...
# 6952   city scrape  Rental unit in Rio de Janeiro · ★4.78 · 1 bedr...
#
#                                              description  \
# 12228                                                NaN
# ...

# %%
train_data.isnull().sum()
# Out:
# source                                             0
# name                                               0
# description                                      458
# neighborhood_overview                              0
# host_id                                            0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               5691
# Length: 61, dtype: int64

# %%
train_data['reviews_per_month'].median()
# Out:
# 0.56

# %%
train_data['reviews_per_month'].fillna(train_data['reviews_per_month'].median(), inplace=True)
test_data['reviews_per_month'].fillna(train_data['reviews_per_month'].median(), inplace=True)

# %%
train_data
# Out:
#                 source                                               name  \
# 14752      city scrape  Rental unit in Copacabana · ★4.93 · 1 bedroom ...
# 2447       city scrape  Condo in Rio de Janeiro · ★4.77 · 1 bedroom · ...
# 12669  previous scrape  Condo in Barra da Tijuca · ★5.0 · 1 bedroom · ...
# 25340      city scrape  Rental unit in Rio de Janeiro · 2 bedrooms · 2...
# 4420       city scrape  Rental unit in Rio de Janeiro · ★4.90 · 2 bedr...
# ...                ...                                                ...
# 29802      city scrape  Rental unit in Rio de Janeiro · 1 bedroom · 2 ...
# 5390       city scrape  Home in Rio de Janeiro · 3 bedrooms · 3 beds ·...
# 860        city scrape  Rental unit in Rio de Janeiro · ★4.91 · 2 bedr...
# 15795      city scrape  Rental unit in Copacabana · ★4.73 · 1 bedroom ...
# 23654      city scrape  Serviced apartment in Rio de Janeiro · ★4.86 ·...
#
#                                              description  \
# ...

# %%
train_data.isnull().sum()
# Out:
# source                                            0
# name                                              0
# description                                     458
# neighborhood_overview                             0
# host_id                                           0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                                 0
# Length: 61, dtype: int64

# %%
most_frequent_description=train_data['description'].mode()[0]
train_data['description'].fillna(most_frequent_description ,inplace=True)
test_data['description'].fillna(most_frequent_description , inplace=True)

# %%
train_data.isnull().sum()
# Out:
# source                                          0
# name                                            0
# description                                     0
# neighborhood_overview                           0
# host_id                                         0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 61, dtype: int64

# %%
most_common_room_type = data['room_type'].mode().iloc[0]
print(f'Most Common Room Type: {most_common_room_type}')
# Out:
# Most Common Room Type: Entire home/apt

# %%
average_reviews_per_month = data['reviews_per_month'].mean()
print(f'Average Reviews Per Month: {average_reviews_per_month:.2f}')
# Out:
# Average Reviews Per Month: 0.97

# %%
top_neighborhoods = data['neighbourhood'].value_counts().head(10)
print('Top Neighborhoods by Listing Count:')
print(top_neighborhoods)
# Out:
# Top Neighborhoods by Listing Count:
# Rio de Janeiro, Brazil                              9065
# Copacabana, Rio de Janeiro, Brazil                  2169
# Barra da Tijuca, Rio de Janeiro, Brazil              709
# Ipanema, Rio de Janeiro, Brazil                      549
# Rio, Rio de Janeiro, Brazil                          538
# Recreio dos Bandeirantes, Rio de Janeiro, Brazil     349
# Botafogo, Rio de Janeiro, Brazil                     321
# Leblon, Rio de Janeiro, Brazil                       300
# Centro, Rio de Janeiro, Brazil                       292
# Flamengo, Rio de Janeiro, Brazil                     206
# Name: neighbourhood, dtype: int64

# %%
average_listings_per_host = data['calculated_host_listings_count'].mean()
print(f'Average Listings Per Host: {average_listings_per_host:.2f}')
# Out:
# Average Listings Per Host: 8.84

# %%
data['last_review'] = pd.to_datetime(data['last_review'])
availability_over_time = data.groupby(data['last_review'].dt.to_period("M"))['availability_365'].mean()
print('Availability Over Time:')
print(availability_over_time)
# Out:
# Availability Over Time:
# last_review
# 2012-02    365.000000
# 2013-01    272.500000
# 2013-02    271.500000
# 2013-05    363.500000
# 2013-06    362.500000
#               ...
# 2023-05    190.300000
# 2023-06    183.142986
# 2023-07    179.611429
# 2023-08    171.566723
# 2023-09    169.560120
# Freq: M, Name: availability_365, Length: 119, dtype: float64

# %%
top_hosts = data['host_name'].value_counts().head(10)
print('Top Hosts by Listing Count:')
print(top_hosts)
# Out:
# Top Hosts by Listing Count:
# Daniel     333
# Rafael     262
# Ricardo    241
# Maria      238
# Rodrigo    238
# Marcelo    225
# Pedro      225
# Ana        219
# Carlos     211
# Eduardo    208
# Name: host_name, dtype: int64

# %%
average_listings_per_host = data['calculated_host_listings_count'].mean()
print(f'Average Listings Per Host: {average_listings_per_host:.2f}')
# Out:
# Average Listings Per Host: 8.84

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Price Distribution Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['price'], bins=50, kde=True)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')
plt.show()
"""
This histogram shows the distribution of Airbnb listing prices.
It helps you understand the range and frequency of different price points in the dataset.
"""

# %%
#Room Type Distribution
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='room_type')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Room Type Distribution')
plt.xticks(rotation=45)
plt.show()
"""
This bar chart displays the distribution of different room types (e.g., entire home, private room, shared room).
It helps you see which type of room is most common among the listings.
"""

# %%
#Availability Over Time
plt.figure(figsize=(12, 6))
plt.xlabel('Time (Year-Month)')
plt.ylabel('Average Availability (365 days)')
plt.grid(True)
plt.show()
"""
This line chart shows how the average availability of listings changes over time, likely in months or years.
It helps identify trends in property availability.
"""

# %%
#Reviews per Month Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['reviews_per_month'].dropna(), bins=50, kde=True)
plt.xlabel('Reviews Per Month')
plt.ylabel('Frequency')
plt.title('Reviews Per Month Distribution')
plt.show()
"""
This histogram illustrates the distribution of the number of reviews per month.
It provides insights into how frequently listings receive reviews.
"""

# %%
#Top Neighborhoods by Listing Count
plt.figure(figsize=(10, 6))
sns.barplot(x=top_neighborhoods.index, y=top_neighborhoods.values)
plt.xlabel('Neighborhood')
plt.ylabel('Listing Count')
plt.title('Top Neighborhoods by Listing Count')
plt.xticks(rotation=45)
plt.show()
"""
This bar chart highlights the neighborhoods with the highest number of listings.
It allows you to identify popular areas for Airbnb rentals.
"""

# %%
#Price Over Time
plt.figure(figsize=(12, 6))
price_over_time.plot(kind='line', marker='o', color='purple')
plt.xlabel('Time (Year-Month)')
plt.ylabel('Average Price')
plt.title('Price Over Time')
plt.grid(True)
plt.show()
"""
This line chart displays the average price of listings over time, typically in months or years.
It helps you understand price trends and seasonality.
"""

# %%
#Top Hosts by Listing Count
plt.figure(figsize=(10, 6))
sns.barplot(x=top_hosts.index, y=top_hosts.values)
plt.xlabel('Host Name')
plt.ylabel('Listing Count')
plt.title('Top Hosts by Listing Count')
plt.xticks(rotation=45)
plt.show()
"""
This bar chart lists the top hosts with the most listings.
It can help you identify hosts who manage a significant number of properties.
These visualizations help you better understand the data and provide insights into various aspects of the Airbnb dataset,
such as price distribution, room type distribution, geographic patterns, temporal and seasonal trends.
You can customize these visuals further to suit your analysis goals and preferences
"""
